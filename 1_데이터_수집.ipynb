# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/Project2-Review/blob/main/1_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%88%98%EC%A7%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium

# %%
import bs4
import json
import requests
import pandas as pd
import numpy as np
import time
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from IPython.display import clear_output
from bs4 import BeautifulSoup

# %%
# 웹 드라이버 실행
driver = webdriver.Chrome('chromedriver')

# %%
# 3) 지연시간 지정 후에 웹브라우저 주소로 이동
# 지연시간 주기 time.sleep(시간)
time.sleep(2)
# 이동 URL
# url = 'https://www.kurly.com/main'
url = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5069036&page=2%22'
# 드라이버객체명.get(이동URL )
driver.get(url)

# %%
html_str = driver.page_source
# 페이지 숲 객체화
soup = BeautifulSoup(html_str)
# 타켓을 품고있는 요소 파악
target_list = soup.select('div.inner_review')
# 원하는 타겟만을 얻기 위한 분리
a= target_list[0].get_text().split('\n\n\n')
a[1]

for i in range(7):
    a = target_list[i].get_text().split('\n\n\n')
    print(a[1])
# Out:
# 맛있는데 할인까지 하니 더좋아요
#
# 맛있어요 닭가슴살 부드럽고 갈릭향 좋아요
#
# 전자렌지용이 아니라 귀찮긴한데 맛은 조아요
#
# 제가 먹은 닭찌중에 젤 맛있어요….. 유명한 이유가 있네요ㅜㅜ 후라이팬에 구워야해서 다른 전자레인지돌려먹어야하는 닭찌보다 귀찮긴하지만 그래도그래도 너무너무 맛있어요 퍽퍽하지 않고 목살?먹는 느낌이에영 ㅜㅜ 쌈장에 상추에 싸먹우면 그냥 삼겹살먹는 느낌 지대로 낼숬을거같아요.. 먹자마자 감탄해서 바로 후기쓰러왔습니다
#
# 운동후 단백질 섭취!
#
# 닭가슴이 이렇게 촉촉하다니 하면서 주변에 소개 많이 했습니다
#
# 한번 먹어보고 재구매합니다!!샐러드에 추가해서 먹으니 가볍고 좋아요!!

# %%
# 페이지 수 확인
print(soup.find_all('a')[-1])
print('='*50)

# 페이지 수 들고오기
a = soup.find_all('a')[-1]
a['href'].split('=')[-1]
# Out:
# <a class="layout-pagination-button layout-pagination-last-page" href="/shop/goods/goods_review_list.php?goodsno=5069036&amp;page=13741">맨 끝 페이지로 가기</a>
# ...
# '13741'

# %%
# 2번 9만 5천개
# 리뷰 데이터를 담을 리스트
review = []

# 상품 리뷰 주소
url2 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5069036&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url2 + str(i)
    if i%10 == 0:
        review2 = pd.DataFrame(review)
        review2.to_csv('./data/리뷰데이터2.csv', encoding = 'utf-8-sig', index = False)
    time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

# 에러 발생시 알려주고 넘어가는 코드
    try:
        for j in range(7):
            a = target_list[j].get_text().split('\n\n\n')
            review.append(a[1].replace('\n',''))

    except IndexError :
        print('잘못된 인덱스입니다')

# %%
# 2번 전체 저장
review22 = pd.DataFrame(review)
review22.to_csv('./data/리뷰데이터22.csv', encoding = 'utf-8-sig', index = False)

# %%
# 3번 9천개
url3 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5059674&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url3 + str(i)
    if i%10 == 0:
        review3 = pd.DataFrame(review)
        review3.to_csv('./data/리뷰데이터3.csv', encoding = 'utf-8-sig', index = False)
    time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

    try:
        for j in range(7):
            a = target_list[j].get_text().split('\n\n\n')
            review.append(a[1].replace('\n',''))

    except IndexError :
        print('잘못된 인덱스입니다')

# %%
# 3번 전체 저장
review33 = pd.DataFrame(review)
review33.to_csv('./data/리뷰데이터33.csv', encoding = 'utf-8-sig', index = False)

# %%
# 4번 7만 2천개
# review = []

url4 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5051264&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url4 + str(i)
    if i%10 == 0:
        review4 = pd.DataFrame(review)
        review4.to_csv('./data/리뷰데이터41.csv', encoding = 'utf-8-sig', index = False)
    time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

    for j in range(7):
        a = target_list[j].get_text().split('\n\n\n')
        review.append(a[1].replace('\n',''))

# %%
# 4번 전체 저장
review44 = pd.DataFrame(review)
review44.to_csv('./data/리뷰데이터44.csv', encoding = 'utf-8-sig', index = False)

# %%
# 5번 5만 7천개
# review = []

url5 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5161908&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url5 + str(i)
    if i%10 == 0:
        review5 = pd.DataFrame(review)
        review5.to_csv('./data/리뷰데이터5.csv', encoding = 'utf-8-sig', index = False)
    time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

    try:
        for j in range(7):
            a = target_list[j].get_text().split('\n\n\n')
            review.append(a[1].replace('\n',''))

    except IndexError :
        print('잘못된 인덱스입니다')

# %%
# 5번 전체 저장
review55 = pd.DataFrame(review)
review55.to_csv('./data/리뷰데이터55.csv', encoding = 'utf-8-sig', index = False)

# %%
# 6번 6만 3천개
url6 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5161784&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url6 + str(i)
    if i%10 == 0:
        review6 = pd.DataFrame(review)
        review6.to_csv('./data/리뷰데이터6.csv', encoding = 'utf-8-sig', index = False)
#     time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

    try:
        for j in range(7):
            a = target_list[j].get_text().split('\n\n\n')
            review.append(a[1].replace('\n',''))

    except IndexError :
        print('잘못된 인덱스입니다')
# Out:
# <class 'int'>
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# ...

# %%
# 6번 전체 저장
review66 = pd.DataFrame(review)
review66.to_csv('./data/리뷰데이터66.csv', encoding = 'utf-8-sig', index = False)

# %%
# 7번 5만 2천개
url7 = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5161907&page='
a = soup.find_all('a')[-1]
last_page = a['href'].split('=')[-1]
last_page = int(last_page)
print(type(last_page))
for i in range(2,last_page):
    url = url7 + str(i)
    if i%10 == 0:
        review7 = pd.DataFrame(review)
        review7.to_csv('./data/리뷰데이터7.csv', encoding = 'utf-8-sig', index = False)
#     time.sleep(1)
    driver.get(url)

    html_str = driver.page_source
    soup = BeautifulSoup(html_str)
    target_list = soup.select('div.inner_review')

    try:
        for j in range(7):
            a = target_list[j].get_text().split('\n\n\n')
            review.append(a[1].replace('\n',''))

    except IndexError :
        print('잘못된 인덱스입니다')
# Out:
# <class 'int'>
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# 잘못된 인덱스입니다
# ...

# %%
# 7번 전체 저장
review77 = pd.DataFrame(review)
review77.to_csv('./data/리뷰데이터77.csv', encoding = 'utf-8-sig', index = False)

# %%
# 전체 데이터 수
len(review)
# Out:
# 115614

# %%
# 전체 데이터 저장
review = pd.DataFrame(review)
review.to_csv('./data/리뷰데이터전체.csv', encoding = 'utf-8-sig', index = False)

# %% [raw]
# # 4) 검색어 입력
# # 원격 크롬웹브라우저에 입력한 검색어 결과가 출력되어야 한다.
#
# time.sleep(2)
#
# # q는 검색 입력창의 name 값
# # driver.find_element_by_css_selector('#gnb_search').send_keys('닭가슴살')
# driver.find_element_by_css_selector('#gnb_search').send_keys('닭가슴살')
# driver.find_element_by_css_selector('#submit').click()

# %% [raw]
# <div class="css-w444a2 e1493ofl1">
# <input id="gnb_search" placeholder="검색어를 입력해주세요" required="" class="css-1b3w0ph e1493ofl3" value="닭가슴살">
# <button class="e1493ofl2 css-n2gba3 e8bjkbi0" size="16" id="delete-search-keyword" tabindex="-1" aria-label="delete-search-keyword" type="button">
# </button>
# <button id="submit" aria-label="submit" class="css-ywxmlw e1493ofl0"></button>
# </div>

# %% [raw]
# # 첫번째 제품 클릭
# driver.find_element_by_css_selector('#container > div > div.css-1d3w5wq.ef36txc5 > div.css-15x6ap3.ef36txc4 > div:nth-child(1)').click()

# %% [raw]
# print(driver.find_element(By.CLASS_NAME, 'content'))

# %% [raw]
# print(driver.find_elements(By.CLASS_NAME, 'board_pg_area').text)

# %% [raw]
# print(driver.find_elements(By.TAG_NAME, 'a'))

# %% [raw]
# # class="board_pg_area"
# driver.find_elements(By.CSS_SELECTOR, '#contents-wrapper > div.board_pg_area > a.layout-pagination-button.layout-pagination-last-page')

# %% [raw]
# # class="board_pg_area"
# target_page = driver.find_elements(By.CSS_SELECTOR, '#contents-wrapper > div.board_pg_area > a.layout-pagination-button.layout-pagination-last-page')
# len(target_page)
